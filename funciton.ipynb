# %%
# function is declare using def function name():

# %% [markdown]
# ## function wihtout arguement ##

# %%
# wap of avg using function
def avg():
    x=eval(input("enter first number"))
    y=eval(input("enter second number"))
    z=eval(input("enter third number"))
    avg=(x+y+z)/3
    round(avg,3)
    print("the average of {},{} and {} is {}".format(x,y,z,avg))
avg()# calling function
# Out:
# enter first number 2
# enter second number 3
# enter third number 4
# the average of 2,3 and 4 is 3.0

# %%
# function using try and exception

def avg():
    try:
        x=eval(input("enter first number"))
        y=eval(input("enter second number"))
        z=eval(input("enter third number"))
        avg=(x+y+z)/3
        round(avg,3)
        print("the average of {},{} and {} is {}".format(x,y2,z,avg))
    except Exception as e:
        print(e)
avg()# calling function
# Out:
# enter first number 1
# enter second number 2
# enter third number 3
# name 'y2' is not defined

# %%
def bill():
    try:
        bill=eval(input("enter the bill amount"))
        tip=eval(input("enter the tip amount"))
        total_bill=bill+tip
        print("the total bill amount of bill {} and tip {} is {}".format(bill,tip,total_bill))
    except Exception as e:
        print(e)
bill()
# Out:
# enter the bill amount 1000
# enter the tip amount 23
# the total bill amount of bill 1000 and tip 23 is 1023

# %%
# wap in function wheater it is evern or odd
import random
print("ist")
print("2nd")
def even_odd():
    try:
        x=random.randint(1,100)
        if x%2==0:
            print("The number {} is even".format(x))
        else:
            print("the number {} is odd".format(x))
    except Excetion as e:
        print(e)
print("calling function")        
even_odd()
# Out:
# ist
# 2nd
# calling function
# The number 78 is even
# done!

# %%
# addition sub and mulplication using function without arguement
def addition():
    try:
        num1=10
        num2=20
        num3=num1+num2
        print("the addition of {} and {} is {}".format(num1,num2,num3))
    except Exception as e:
        print(e)
def multiplication():
    try:
        num1=10
        num2=20
        num3=num1*num2
        print("the multiplication  of {} and {} is {}".format(num1,num2,num3))
    except Exception as e:
        print(e)

def division():
    try:
        num1=10
        num2=20
        num3=num1/num2
        print("the multiplication  of {} and {} is {}".format(num1,num2,num3))
    except Exception as e:
        print(e)
# calling of function
addition()
multiplication()
division()
# Out:
# the addition of 10 and 20 is 30
# the multiplication  of 10 and 20 is 200
# the multiplication  of 10 and 20 is 0.5

# %% [markdown]
# ### funciton with argument ###

# %%
# def function_name(arguements)
def add(n1,n2):
    try:
        num3=n1+n2
        print("the addition is ",num3)
    except Exception as e:
        print(e)
add(1,2)
# Out:
# the addition is  3

# %%
# def function_name(arguements)
def add(n1,n2):
    try:
        num3=n1+n2
        print("the addition is ",num3)
    except Exception as e:
        print(e)
add(1)# will through error as two agrument mentioned
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 9
#       7     except Exception as e:
#       8         print(e)
# ----> 9 add(1)
#
# TypeError: add() missing 1 required positional argument: 'n2'

# %%
# def function_name(arguements)
def add():
    try:
        num3=n1+n2
        print("the addition is ",num3)
    except Exception as e:
        print(e)
add(100,200) # throuhg error as during defination no argument in the function
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 8
#       6     except Exception as e:
#       7         print(e)
# ----> 8 add(100,200)
#
# TypeError: add() takes 0 positional arguments but 2 were given

# %%
# def function_name(arguements)
x1=eval(input("enter a number"))
x2=eval(input("enter a second number"))
def add(n1,n2): # n1=x1, n2=x2
    try:
        num3=n1+n2
        print("the addition is ",num3)
    except Exception as e:
        print(e)
add(x1,x2)# passing the variable
# Out:
# enter a number 1
# enter a second number 2
# the addition is  3

# %%
# wap in function wheater it is evern or odd using positional arg
import random
n=eval(input("enter a number"))
print("ist")
print("2nd")
def even_odd(x):
    try:
        if x%2==0:
            print("The number {} is even".format(x))
        else:
            print("the number {} is odd".format(x))
    except Excetion as e:
        print(e)
even_odd(n)
# Out:
# enter a number 3
# ist
# 2nd
# the number 3 is odd

# %%
a=eval(input("enter first number"))
b=eval(input("enter second number"))       
def sum1(a,b):
    c=a+b
    print(c)
sum1(2,3)# it will take only that arguement which are use in calling of function not global variable
# Out:
# enter first number 1
# enter second number 1
# 5

# %% [markdown]
# ### note actual and formal argument name can be same ###

# %%
bil_amount=eval(input("enter the bill amount"))
tip_amount=eval(input("enter the tip amount"))
def bill(bil_amount, tip_amount):
    try:
        total_bill=bil_amount+tip_amount
        print("the total bill is", total_bill)
    except Exception as e:
        print(e)
bill(bil_amount,tip_amount)
# Out:
# enter the bill amount 12
# enter the tip amount 23
# the total bill is 35

# %%
# WAP ask there user
# get one random number between 1 to 20
# enter a number
# compare these two number
# if both are same: print("you won")
# else: print(lost)
#M-1: Write in normal way
#M-2: Create a function with out argument
#M-3: Create a function with argument

# %%
# normal way
import random
x=random.randint(1,20)
y=eval(input("enter a number"))
if x==y:
    print("the random number {} and number enter by you is {} both equal you won.".format(x,y))
else:
    print("the random number  {} and number enter by you {} is not same hence you loss".format(x,y))
# Out:
# enter a number 8
# the random number  20 and number enter by you 8 is not same hence you loss

# %%
# function without agrgument
import random
def compare():
    try:      
        x=random.randint(1,20)
        y=eval(input("enter a number"))
        if x==y:
            print("the random number {} and number enter by you is {} both equal you won.".format(x,y))
        else:
            print("the random number  {} and number enter by you {} is not same hence you loss".format(x,y))
    except Exception as e:
        print(e)
compare()
# Out:
# enter a number 2
# the random number  19 and number enter by you 2 is not same hence you loss

# %%
import random
x=random.randint(1,20)  
y=eval(input("enter a number"))
def compare(a,b):
    # no varialbe pass but they using global variable x,y
    try:      
        if a==b:
            print("the random number {} and number enter by you is {} both equal you won.".format(a,b))
        else:
            print("the random number  {} and number enter by you {} is not same hence you loss".format(a,b))
    except Exception as e:
        print(e)
compare(x,y)
# Out:
# enter a number 1
# the random number  17 and number enter by you 1 is not same hence you loss

# %%
# function with agrgument
import random
x=random.randint(1,20)   # global variable can be use by anyone in the program
                        # so if global vaible present then don't declare the same local vaible in function 
y=eval(input("enter a number"))
def compare():
    # no varialbe pass but they using global variable x,y
    try:      
        if x==y:
            print("the random number {} and number enter by you is {} both equal you won.".format(x,y))
        else:
            print("the random number  {} and number enter by you {} is not same hence you loss".format(x,y))
    except Exception as e:
        print(e)
compare()

# %%
# function with agrgument by passiing only single argument 
# always pass number of user defined variable in function 
# x is randomaly generate 
import random
x=eval(input("enter a number"))
def compare(a):
    try:
        b=random.randint(1,20)
        if a==b:
            print("the random number {} and number enter by you is {} both equal you won.".format(b,a))
        else:
            print("the random number  {} and number enter by you {} is not same hence you loss".format(b,a))
    except Exception as e:
        print(e)
compare(x)
# Out:
# enter a number 1
# the random number  6 and number enter by you 1 is not same hence you loss

# %%
import random

def compare(b,a):
    try:
        if a==b:
            print("the random number {} and number enter by you is {} both equal you won.".format(b,a))
        else:
            print("the random number  {} and number enter by you {} is not same hence you loss".format(b,a))
    except Exception as e:
        print(e)
compare(random.randint(1,20),eval(input("enter a number")))   # we can pass the value directly also
# Out:
# enter a number 1
# the random number  11 and number enter by you 1 is not same hence you loss

# %%
# WAP ask the user enter salary
# ask the user enter tax percentage
# calulate total tax to pay

# %%
# the formal and actual argment name can be same
salary=eval(input("enter ther salary"))
tax=eval(input("enter tax %"))
def tax_pay(salary,tax):
    try:
        ta=(tax*salary)/100
        print("the tax you need to pay is of salary {} is {}".format(salary,ta))
    except Exception as e:
        print(e)
tax_pay(salary,tax)
# Out:
# enter ther salary 100
# enter tax % 1
# the tax you need to pay is of salary 100 is 1.0

# %%
# the formal and actual argument it can be different but prefer differnet
val1=eval(input("enter ther salary"))
val2=eval(input("enter tax %"))
def tax_pay1(salary,tax):
    try:
        ta=(tax*salary)/100
        print("the tax you need to pay is of salary {} is {}".format(salary,ta))
    except Exception as e:
        print(e)
tax_pay1(val1,val2)
# Out:
# enter ther salary 2000
# enter tax % 2
# the tax you need to pay is of salary 2000 is 40.0

# %%
# the formal and actual argument it can be different but prefer differnet

def tax_pay1(salary,tax):
    try:
        ta=(tax*salary)/100
        print("the tax you need to pay is of salary {} is {}".format(salary,ta))
    except Exception as e:
        print(e)
tax_pay1(eval(input("enter ther salary")),eval(input("enter tax %")))  # we can pass the value intilisation during callling
# Out:
# enter ther salary 100
# enter tax % 1
# the tax you need to pay is of salary 100 is 1.0

# %%
## if global and local varibale have same name then it will take the value of local variable in function if assign inside function
x=8
def fun():
    x=7
    print(x)
fun()
# Out:
# 7

# %%
## if global and local varibale have same name then it will take the value of local variable in function if assign inside function
## if no assignment is done inside the function of the same name variable then it will take value of gloabal 
x=8
def fun():
    
    print(x)
fun()
# Out:
# 8

# %%
# we can pass the value directly
def tax_pay1(salary,tax):
    try:
        ta=(tax*salary)/100
        print("the tax you need to pay is of salary {} is {}".format(salary,ta))
    except Exception as e:
        print(e)
tax_pay1(1000,10)  # we can pass the value directly
# Out:
# the tax you need to pay is of salary 1000 is 100.0

# %% [markdown]
# ## default parameter ##

# %%
def avg(a,b,c=10):# c is fixed if no valuse will pass from the call it will take default c=10
    add=a+b+c
    avg=add/3
    print("the average is :",avg)
avg(1,2)
# Out:
# the average is : 4.333333333333333

# %%
def avg(a,b=10,c): # defauld arguement must be in last other it wii through error
    add=a+b+c
    avg=add/3
    print("the average is :",avg)
avg(1,2)
# Out:
#   Cell In[30], line 1
#     def avg(a,b=10,c): # defauld arguement must be in last other it wii through error
#                    ^
# SyntaxError: parameter without a default follows parameter with a default

# %%
def avg(a,b=10,c): # defauld arguement must be in last othe wise it will through error 
    add=a+b+c
    avg=add/3
    print("the average is :",avg)
avg(1,2,3)
# Out:
#   Cell In[31], line 1
#     def avg(a,b=10,c): # defauld arguement must be in last other it wii through error
#                    ^
# SyntaxError: parameter without a default follows parameter with a default

# %%
def avg(a=10,b=10,c): # defauld arguement must be in last othe wise it will through error 
    add=a+b+c
    avg=add/3
    print("the average is :",avg)
avg(1,2,3)
# Out:
#   Cell In[32], line 1
#     def avg(a=10,b=10,c): # defauld arguement must be in last othe wise it will through error
#                       ^
# SyntaxError: parameter without a default follows parameter with a default

# %%
# it will work
def avg(a,b=10,c=20): # defauld arguement must be in last othe wise it will through error 
    print(a,b,c)
    add=a+b+c
    avg=add/3
    print("the average is :",avg)
avg(1,2,3)
# Out:
# 1 2 3
# the average is : 2.0

# %%
x=eval(input("enter a number"))
def square(a):
    sq=a*a
    print("the square of the number is", sq)
square()   # if no argument will pass it will show error as one arguement must pass during defination of square function 
#TypeError: square() missing 1 required positional argument: 'a'
# Out:
# enter a number 4
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 5
#       3     sq=a*a
#       4     print("the square of the number is", sq)
# ----> 5 square()
#
# TypeError: square() missing 1 required positional argument: 'a'

# %%
#using default argument 
def square(a=10):
    sq=a*a
    print("the square of the number is", sq)
square()
# Out:
# the square of the number is 100

# %%
#using default argument 
def square(a=10):
    sq=a*a
    print("the square of the number is", sq)
square(20)   # now a value will be 20
# Out:
# the square of the number is 400

# %%
#complex
complex() #0j # here is two default value real=0, imag=o if no argument will pass the default valuse be use
complex(1) # 1+oj
complex(1,3) # 1+3j
# Out:
# (1+3j)

# %%
from random import randint
randint(1,20) # in this there is not defaul parameter
# if no pass the value then it will through error as it required two arguement
randint()# error TypeError: Random.randint() missing 2 required positional arguments: 'a' and 'b'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[48], line 4
#       2 randint(1,20) # in this there is not defaul parameter
#       3 # if no pass the value then it will through error as it required two arguement
# ----> 4 randint()
#
# TypeError: Random.randint() missing 2 required positional arguments: 'a' and 'b'

# %%
# wap to find the area of circle 
# Formulae: pi*radius*radius
# import math, math.pi
# Basic method
# With out arguments
# With arguments
# Default

# %%
import math
pi=math.pi
r=eval(input("enter the radius of circle"))
area=pi*r*r
print("the area of circle is ", round(area,2))
# Out:
# enter the radius of circle 3
# the area of circle is  28.27

# %%
# using without argument function
def area_circle():
    try:
        r=eval(input("enter the radius of circle")) # when define function wihtout arguement always assign the required variabl 
        area=pi*r*r                                 # inside function
        print("the area of circle is", round(area,2))
    except Exception as e:
        prin(e)
area_circle()
# Out:
# enter the radius of circle 4
# the area of circle is 50.27

# %%
# using with argument function
r=eval(input("enter the radius of circle"))
def area_circle(r):
    try:
        area=pi*r*r                                
        print("the area of circle is", round(area,2))
    except Exception as e:
        prin(e)
area_circle(r)
# Out:
# enter the radius of circle 2
# the area of circle is 12.57

# %%
# using default argument function
def area_circle(r=4):
    try:
        area=pi*r*r                                
        print("the area of circle is", round(area,2))
    except Exception as e:
        prin(e)
area_circle()  # default r=4
# Out:
# the area of circle is 50.27

# %%
# using default argument function
def area_circle(r=4):
    try:
        area=pi*r*r                                
        print("the area of circle is", round(area,2))
    except Exception as e:
        prin(e)
area_circle(10)  # default r=4
                 # now change with r=10
# Out:
# the area of circle is 314.16

# %% [markdown]
# ### note you need to provide the argument value before the calling of function anywhere after calling
#  it will through error ###

# %% [markdown]
# ### calculator using functio ###

# %%
# defining all the function 
import time
def add(a,b):
    print("we are doing addition")
    print("the sum of {} and {} is {}".format(a,b,a+b))
def sub(a,b):
    print("we are doing substraction")
    print("the subtraction of {} and {} is {}".format(a,b,a-b))
def mul(a,b):
    print("we are doing multiplication")
    print("the multiplication of {} and {} is {}".format(a,b,a*b))

def div(a,b):
     print("we are doing division")
     print("the division of {} and {} is {}".format(a,b,a/b))

    
#defining main function to enter the operation and values
def main():
    print("Welcome")
    print("*************************************************")
    print("**** Here are options****")
    time.sleep(1)
    # printing operations
    print("For addition press + ")
    print("For multiplication press * ")
    print("For division press / ")
    print("For addition press - ")
    op=input("Please choose which operation you want to perform form above")
    time.sleep(0.3)
    # taking numbers as input from users
    time.sleep(1)
    
    # calling each function 
    if op=="+":
        # taking input if operation match this is done becuase if invalid input enter no value will ask from user
        x=eval(input("Enter first number:"))
        y=eval(input("Enter second number:"))
        add(x,y)
    elif op=="-":
        x=eval(input("Enter first number:"))
        y=eval(input("Enter second number:"))
        sub(x,y)
    elif op=="*":
        x=eval(input("Enter first number:"))
        y=eval(input("Enter second number:"))
        mul(x,y)
    elif op=="/":
        x=eval(input("Enter first number:"))
        y=eval(input("Enter second number:"))
        div(x,y)
    else:
        print("Please choose the correct option")


# calling main function and then main function will call the required operation as per the input
main()
print("Thank you !")
# Out:
# Welcome
# *************************************************
# **** Here are options****
# For addition press +
# For multiplication press *
# For division press /
# For addition press -
# Please choose which operation you want to perform form above *
# Enter first number: 2
# Enter second number: 4
# we are doing multiplication
# the multiplication of 2 and 4 is 8
# Thank you !

# %% [markdown]
# ### return ###

# %%
import math
pi=math.pi
r=eval(input("enter the radius of circle"))
def area_circle(r):
    try:
        area=pi*r*r                                
        print("the area of circle is", round(area,2))
    except Exception as e:
        prin(e)
area_circle(r)  
print(area) # try to access the area variable outside the function
# it will through as area is local varialbe of area_circle function and we can't access outside 
# as function is not return anything that is why you can't use this
# to use this return the value from the function 
# you can return any number of variable from function using return keyword but to recive the return variable
# number of recive variable must be equal to number of return variable
# Out:
# enter the radius of circle 2
# the area of circle is 12.57
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 11
#       9         prin(e)
#      10 area_circle(r)
# ---> 11 print(area)
#
# NameError: name 'area' is not defined

# %%
# example

# %%
import math
pi=math.pi
r=eval(input("enter the radius of circle"))
def area_circle(r):
    try:
        area=pi*r*r                                
        print("the area of circle is", round(area,2))
        return (area) 
    except Exception as e:
        prin(e)
Area=area_circle(r)# storing the return area value in Area  
print(Area,Pi) # as function now return the area outside functin at the time call store in Area now you can access the area 
# using Area varible outside the function
# Out:
# enter the radius of circle 3
# the area of circle is 28.27
# 28.274333882308138 3.141592653589793

# %%
import math

r=eval(input("enter the radius of circle"))
def area_circle(r):
    try:
        pi=math.pi
        area=pi*r*r                                
        print("the area of circle is", round(area,2))
        return (area, pi)  # returning two varible so two variable require at time of call 
    except Exception as e:
        prin(e)
Pi, Area=area_circle(r)# storing the return area value in Area  
print("area=",Area,"pi=",Pi) # as function now return the area and pi outside functin at the time call store in Area and Pi now you can access the area 
# using Area and Pi varible outside the function
# Out:
# enter the radius of circle 4
# the area of circle is 50.27
# area= 3.141592653589793 pi= 50.26548245743669

# %%
# avg using return

# %%
import math

r=eval(input("enter the radius of circle"))
def area_circle(r):
    try:
        pi=math.pi
        area=pi*r*r                                
        print("the area of circle is", round(area,2))
        return (area, pi)  # returning two varible so two variable require at time of call 
    except Exception as e:
        prin(e)
Area=area_circle(r)# storing the return area and pi value in single variable Area as only one varible use to store it will run not erro 
print("area=",Area) # as function now return the area and pi outside functin at the time call store in Area and Pi now you can access the area 
# but in this case you can't able  to  use the area and pi value separetely
# Out:
# enter the radius of circle 3
# the area of circle is 28.27
# area= (28.274333882308138, 3.141592653589793)

# %%
    def avg():
        try:
            a=eval(input("enter first number"))
            b=eval(input("enter second number"))
            c=eval(input("enter third number"))
            add=a+b+c
            avg=add/3
            return avg # you can return within the bracket or without bracket  return(avg) and return avg both valid
        except Exception as e:
            print(e)
# calling of function 
Avg,b=avg()
print("the average is:",Avg, b)
# Out:
# enter first number 4
# enter second number 5
# enter third number 4
# the average is: 4.333333333333333 4

# %%
# with argument
a=eval(input("enter first number"))
b=eval(input("enter second number"))
def avg(x,y,z=40): # z default 
        try:
            add=x+y+z
            avg=add/3
            return avg, add # you can return within the bracket or without bracket  return(avg) and return avg both valid
            # avg  returning two values one is avg which store in Avg and another  is add which store in Add
        except Exception as e:
            print(e)
# calling of function 
Avg, Add=avg(a,b)
print("the average is:",Avg, "and add is ", Add )
# Out:
# enter first number 3
# enter second number 5
# the average is: 16.0 and add is  48

# %%
# laregest number among three using return 
def largest(a,b,c):
    try:
        if a>=b and a>=c:
            return a
            
        elif b>=a and b>=c:
            return b
        else:
            return c
    except Exception as e:
        print(e)
x=eval(input("enter first number "))        
y=eval(input("enter first number "))        
z=eval(input("enter first number ")) 
large=largest(x,y,z)
print("the largest number among {}, {} and {} is {}".format(x,y,z,large))
# Out:
# enter first number  10
# enter first number  2
# enter first number  3
# the largest number is 10
# the largest number among 10, 2 and 3 is 10

# %%
# laregest number among three using without  return 
def largest(a,b,c):
    try:
        if a>=b and a>=c:
            print("the largest number is {}".format(a))
        elif b>=a and b>=c:
            print("the largest number is {}".format(b))
        else:
            print("the largest number is {}".format(c))
    except Exception as e:
        print(e)
x=eval(input("enter first number "))        
y=eval(input("enter first number "))        
z=eval(input("enter first number ")) 
largest(x,y,z)
# Out:
# enter first number  1
# enter first number  2
# enter first number  3
# the largest number is 3

# %%
def largest(a,b,c):
    try:
        if a>=b and a>=c:
            return a
            
        elif b>=a and b>=c:
            return b
        else:
            return c
    except Exception as e:
        print(e)
x=eval(input("enter first number "))        
y=eval(input("enter first number "))        
z=eval(input("enter first number ")) 
# call inside the print
#print("the largest number is ",largest(x,y,z))
print("the largest number among {}, {} and {} is {}".format(x,y,z,largest(x,y,z)))
# Out:
# enter first number  1
# enter first number  2
# enter first number  3
# the largest number amont 1, 2 and 3 is 3

# %%
# we can direclty return wihtout storing any value in varialbe
# with argument
a=eval(input("enter first number"))
b=eval(input("enter second number"))
c=eval(input("enter third number"))
def avg(x,y,z):
        try:
            return(x+y+z,(x+y+z)/3) # directly return without storing in into vairlabe avg and sun
        except Exception as e:
            print(e)
# calling of function 
Add, Avg=avg(a,b,c)
print("the average is:",Avg, "and add is ", Add )
# Out:
# enter first number 4
# enter second number 4
# enter third number 4
# the average is: 4.0 and add is  12

# %%
# directly  return wihtout storing 
def add(a,b):
    return (a+b)
def sub(a,b):
    return (a-b)   
def mul(a,b):
    return (a*b)    
def div(a,b):
    return (round(a/b,2))
Sum=add(10,20)
Sub=sub(10,20)
Mul=mul(10,20)
Div=div(10,20)
print(Sum,Sub,Mul,Div)
# Out:
# 30 -10 200 0.5

# %%
# all method operatin return by one method

# %%
def aggre(a,b):
    return(a+b,a-b,a*b,(a/b))# four value return so four varialbe need to store
a,s,m,d=aggre(10,20)    
#print(a,s,m,round(d,2))
# or directly  recieve all four in print
print(aggre(10,20)) all four print without storing in four variable
# Out:
# (30, -10, 200, 0.5)

# %%
def aggre(a,b):
    return(a+b,a-b,a*b,(a/b))# four value return so four varialbe need to store
a=aggre(10,20)    
# all four operation store in only a 
# it will run if only one varible  recieve or all required number otherwise through erro
print(a)
# Out:
# (30, -10, 200, 0.5)

# %%
def aggre(a,b):
    return(a+b,a-b,a*b,(a/b))# four value return so four varialbe need to store
a,b=aggre(10,20)  # error   
# all four operation store in only a 
# it will run if only one varible  recieve or all required number otherwise through erro
print(a)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[60], line 3
#       1 def aggre(a,b):
#       2     return(a+b,a-b,a*b,(a/b))# four value return so four varialbe need to store
# ----> 3 a,b,c=aggre(10,20)  # error
#       4 # all four operation store in only a
#       5 # it will run if only one varible  recieve or all required number otherwise through erro
#       6 print(a)
#
# ValueError: too many values to unpack (expected 3)

# %%
# we can write in single also 
# directly  return wihtout storing if you are giving indendation give properly ohter wise without indentation it will work but use for 
# only single line 
def add(a,b):return (a+b)
def sub(a,b):return (a-b)   
def mul(a,b):return (a*b)    
def div(a,b):return (round(a/b,2))
Sum=add(10,20)
Sub=sub(10,20)
Mul=mul(10,20)
Div=div(10,20)
print(Sum,Sub,Mul,Div)
# Out:
# 30 -10 200 0.5

# %%
def add(a,b):return (a+b)
def sub(a,b):return (a-b)   
def mul(a,b):return (a*b)    
def div(a,b):return (round(a/b,2))
Sum=add(10,20)
Sub=sub(10,20)
Mul=mul(10,20)
Div=div(10,20)
print(Sum,Sub,Mul,Div)
# Out:
# 30 -10 200 0.5

# %% [markdown]
# ### local variable ###
# - the variable whichh define inside the function and can be use only inside  the function
# - it can't use outside function
# - if want to use outside the function return that value

# %%
def add():
    n1=10 # n1 and n2 are local variable
    n2=20
    print(n1+n2)
    
add()    
    
print(n1)# can't access outside
# Out:
# 30
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[63], line 8
#       4     print(n1+n2)
#       6 add()
# ----> 8 print(n1)
#
# NameError: name 'n1' is not defined

# %% [markdown]
# ### global  variable ###
# - the varible which declare outside the function and can be use anywhere throughout the program
# - so global variable declare before the call of function
# -# if the global varible is decalre and the same variable is used by function then there is no need to
#  pass the valuse in arguement with call as it is global

# %%
n1=10 # n1 and n2 are global variable
n2=20
def add():
    print(n1+n2) # n1 and n2 are global so there is no need to pass the argument in add
    
add()
# Out:
# 30

# %%
def add():
    print(n5+n6) # n5 and n6 are global  it can be declare any where from the program the can access by any one
n5=20
n6=30
add()
# Out:
# 50

# %%
# Out:
# 20
# 50

# %%
# in fun with arguement you need declare the passing value before the call of function as during 
# execution it will not able to find the value
def add(x1,y1):
    print(x1+y1) # n1 and n2 are global so there is no need to pass the argument in add
    
add(n8,n9) 
n8=10 
n9=39
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[76], line 4
#       1 def add(x1,y1):
#       2     print(x1+y1) # n1 and n2 are global so there is no need to pass the argument in add
# ----> 4 add(n8,n9)
#       5 n8=10
#       6 n9=39
#
# NameError: name 'n8' is not defined

# %%
#*** note declare  global variable  before the calling of the function after call it  will not wrok *** 
# as variable is not defined till yet
def add():
    print(n9+n10) # n1 and n2 are global so there is no need to pass the argument in add
    
add() 
n9=10 
n10=39.6
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[77], line 4
#       1 def add():
#       2     print(n9+n10) # n1 and n2 are global so there is no need to pass the argument in add
# ----> 4 add()
#       5 n9=10
#       6 n10=39.6
#
# Cell In[77], line 2, in add()
#       1 def add():
# ----> 2     print(n9+n10)
#
# NameError: name 'n9' is not defined

# %%
# if the global varible is decalre and the same variable is used by function then there is no need to 
# pass the valuse in arguement with call as it is global

def add():
    print(x1+y1) # n1 and n2 are global so there is no need to pass the argument in add
x1=3000
y1=4
add()
# Out:
# 3004

# %%
print(D)
D=h   # error  printing D but d is not intialisize yet it is next line so python is  step step by execution
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[79], line 1
# ----> 1 print(D)
#       2 D=h
#
# NameError: name 'D' is not defined

# %%
def avg():
    a0=10 # local variables
    b0=20
    c0=30
    print((a0+b0+c0)/3)
avg()    
print(a0)# we can't access the local variable outside the function
# to access the local variable return that  valuse only then you  can use
# Out:
# 20.0
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[83], line 7
#       5     print((a0+b0+c0)/3)
#       6 avg()
# ----> 7 print(a0)
#
# NameError: name 'a0' is not defined

# %%
# access local variable using return
def avg():
    a0=10 # local variables
    b0=20
    c0=30
    print((a0+b0+c0)/3)
    return(a0)
A=avg() # using return a0 local varible access as it return by avg
print(A)
# Out:
# 20.0
# 10

# %%
n1=20
n2=30
def addition():
    n1=200
    n2=300
    add=n1+n2
    print("the addition of {} and {} is {}".format(n1,n2,add))
addition()
print(n1) # global variabel as n1 inside the function can't access without return outside
# Out:
# the addition of 200 and 300 is 500
# 20

# %%
n111=20
n222=30
def addition(n111=800):
    n111=200
    n222=300
    add=n111+n222
    print("the addition of {} and {} is {}".format(n1,n2,add))
    return(n111)
n111=addition(700) # now n111 is return by fun n111=200
print(n111)
# Out:
# the addition of 20 and 30 is 500
# 200

# %%
n1=20
n2=30
def addition(n1=800):
    n1=200
    n2=300
    add=n1+n2
    print("the addition of {} and {} is {}".format(n1,n2,add))
addition()
print(n1)

# %%
n111=20
n222=30
def addition(n111=800):
    n111=200
    n222=300
    add=n111+n222
    return(n111)
    # after return from the function control return to the call now next line after the  return will not execute
    print("the addition of {} and {} is {}".format(n1,n2,add))
    
n111=addition(700) # now n111 is return by fun n111=200 local 
print(n111)
# Out:
# 200

# %%
n888=20
n2=30
def addition():
    n888=200
    n2=300
    add=n1+n2
    print("the addition of {} and {} is {}".format(n888,n2,add))
addition()
print(n888) # 20 gloabl variable can't access outside
# Out:
# the addition of 200 and 300 is 320
# 20

# %%
n111=20
n222=30
def addition(n111=800):
    n111=200
    n222=300
    add=n111+n222 # 500
    print("the addition of {} and {} is {}".format(n1,n2,add))
addition(700) # now n111 is return by fun n111=200
print(n111)  # 20 global
# Out:
# the addition of 20 and 30 is 500
# 20

# %%
n111=20
n222=30
def addition(n111=800):
    n222=300
    add=n111+n222
  
    print("the addition of {} and {} is {}".format(n1,n2,add))
    return(n111)
n111=addition(700) # now n111 is return by fun n111=200
print(n111)
# Out:
# the addition of 20 and 30 is 1000
# 700

# %% [markdown]
# ### note to use  the local variable outside the function without retur ###
# - use global keyword as global variable_name
# - varible_name=39
# - now  the local varible become the global outside function can access
# - you can declare multiple variable as global
# - using global var1,var not intiatlise here initiatgle in next line

# %%
# Out:
# the addition of 200 and 300 is 500
# 200
# the addition is  500

# %%
n111=20
n222=30
def addition():
    # without makeing add as global it will throuth error outside
    global n111
    n111=200
    n222=300
    add1=n111+n222
    print("the addition of {} and {} is {}".format(n111,n222,add1))
    
addition() # now n111 is return by fun n111=200 local 
print(n111)
print("the addition is ",add1)
# Out:
# the addition of 200 and 300 is 500
# 200
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[112], line 13
#      11 addition() # now n111 is return by fun n111=200 local
#      12 print(n111)
# ---> 13 print("the addition is ",add1)
#
# NameError: name 'add1' is not defined

# %%
n111=20
n222=30
def addition():
    # making n111 and add as global
    global n111,add
    n111=200
    n222=300
    add=n111+n222
    print("the addition of {} and {} is {}".format(n111,n222,add))
    
addition() # now n111 is return by fun n111=200 local 
print(n111)
print("the addition is ",add)
# Out:
# the addition of 200 and 300 is 500
# 200
# the addition is  500

# %%
# if any variable is in assignment in function it will treat as local and in second step it will search for value 
# if value  not then through error it will not look into the global if present also
# it is applicable only on assignment but you can print and other  operatin you can do
n_=10
def updated():
    n_=n_+1 # n_ local it will look for value
    print("n_ value inside function is:",n_)
updated() # 110
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[150], line 8
#       6     n_=n_+1 # n_ local it will look for value
#       7     print("n_ value inside function is:",n_)
# ----> 8 updated()
#
# Cell In[150], line 6, in updated()
#       5 def updated():
# ----> 6     n_=n_+1 # n_ local it will look for value
#       7     print("n_ value inside function is:",n_)
#
# UnboundLocalError: cannot access local variable 'n_' where it is not associated with a value

# %% [markdown]
#  ###Key rule to remember
#
# 👉 If a variable is assigned inside a function, Python always treats it as local (unless declared global or nonlocal).
# So even though n_ exists globally, your assignment n_ = 10 + n_ forces Python to treat it as a local variable — and since you try to read it before assigning, you get the error.###

# %%
# but you can print the value of n_ in that case it will look on globle
n_=10
def updated():
    print("n_ value inside function is:",n_)
updated() # 110
# Out:
# n_ value inside function is: 10

# %%
# it will work as no assignment is doing on n_1 it will fetch the value from global
n_=10
n_1=20
def updated():
    n_=10+n_1
    print("n_ value inside function is:",n_)
updated() # 110
# Out:
# n_ value inside function is: 30

# %% [markdown]
# ### note in if you  are doing any operating inside function through local variable it must be intiatelise ###

# %%
n_=10
n_1=20
def updated():
    n_=10+n_ # error
    print("n_ value inside function is:",n_)
updated() # 110
print("value outside the function ",n_)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[154], line 6
#       4     n_=10+n_ # error
#       5     print("n_ value inside function is:",n_)
# ----> 6 updated() # 110
#       7 print("value outside the function ",n_)
#
# Cell In[154], line 4, in updated()
#       3 def updated():
# ----> 4     n_=10+n_ # error
#       5     print("n_ value inside function is:",n_)
#
# UnboundLocalError: cannot access local variable 'n_' where it is not associated with a value

# %%
# no error as in assingment of n_ before we intiatlize the value of n_
n_=10
n_1=20
def updated():
    # n_ is in assingment so it must intiatlise
    n_=10 
    n_=10+n_
    print("n_ value inside function is:",n_)
updated() # 110
print("value outside the function ",n_)
# Out:
# n_ value inside function is: 20
# value outside the function  10

# %%
# if we can make it global then it will intialize with global value now ther is no need to intialize
# with value as now it treat as global
n_=10
n_1=20
def updated():
    # n_ is in assingment so it must intiatlise
    global n_
    n_=10+n_
    print("n_ value inside function is:",n_)
updated() # 110
# Out:
# n_ value inside function is: 20

# %%
n7=10
def updated():
    n7=10
    n7=10+n7
    print("n7 value inside function is:",n7)
updated() #
print("n7 value outside the function",n7)
# Out:
# n7 value inside function is: 20
# n7 value outside the function 10

# %%
# acess n7 local variable outside the function without return using global
n7=10
def updated():
    global n7
    n7=10
    n7=10+n7
    print("n7 value inside function is:",n7)
updated() #
print("n7 value outside the function",n7)
# Out:
# n7 value inside function is: 20
# n7 value outside the function 20

# %%
n7=10
n8=20
def updated():
    print(" sum is:",n7+n8)
updated() #
# Out:
#  sum is: 30

# %% [markdown]
# ** function in function **
# - when inside a function we calling some  other function

# %%
def greet():
    print("hello")

def name():
    print("pyhton")

greet()
name()
# Out:
# hello
# pyhton

# %%
def greet():
    print("hello")
    name() # greet calling name

def name():
    print("pyhton")

greet()
# Out:
# hello
# pyhton

# %%
def greet():
    print("hello")
   

def name():
    print("pyhton")
    greet()
name()
# Out:
# pyhton
# hello

# %%
def greet():
    print("hello")
    name()
   

def name():
    print("pyhton")
    greet()
name() # infinite loop
print("how do you do ")
greet()
# Out:
# pyhton
# hello
# pyhton
# hello
# pyhton
# hello
# pyhton
# hello
# pyhton
# hello
# pyhton
# hello
# pyhton
# hello
# pyhton
# hello
# pyhton
# hello
# pyhton
# hello
# pyhton
# hello
# pyhton
# hello
# pyhton
# hello
# pyhton
# hello
# pyhton
# hello
# pyhton
# hello
# pyhton
# hello
# pyhton
# hello
# pyhton
# hello
# pyhton
# hello
# pyhton
# hello
# pyhton
# hello
# pyhton
# hello
# pyhton
# hello
# pyhton
# hello
# pyhton
# hello
# pyhton
# hello
# pyhton
# hello
# pyhton
# hello
# pyhton
# hello
# pyhton
# hello
# pyhton
# hello
# pyhton
# hello
# pyhton
# hello
# pyhton
# hello
# pyhton
# hello
# pyhton
# hello
# pyhton
# hello
# pyhton
# hello
# pyhton
# hello
# pyhton
# hello
# pyhton
# hello
# pyhton
# hello
# pyhton
# hello
# pyhton
# hello
# pyhton
# hello
# pyhton
# hello
# pyhton
# hello
# pyhton
# hello
# pyhton
# hello
# pyhton
# hello
# pyhton
# hello
# pyhton
# hello
# pyhton
# hello
# pyhton
# hello
# pyhton
# hello
# pyhton
# hello
# pyhton
# hello
# pyhton
# ...

# %%
def fun1():
    print("hello")
    print(3+8)
print("jagte raho")

def fun2():
    print("i am the 2nd")
    print(8+4)
    fun1()
fun1() 
print("hi how are you")    
def fun3():
    print("kaise ho")
    print("5+8")
print("your are late")
def fun():
    print("i am the boss")
    fun1()
    fun3()
    fun2()
fun()
# Out:
# jagte raho
# hello
# 11
# hi how are you
# your are late
# i am the boss
# hello
# 11
# kaise ho
# 5+8
# i am the 2nd
# 12
# hello
# 11

# %%
# jagte raho
# hello 
#11
#hi how are you
#you are late
# iam the boss
#hello
# 11
#kaise ho 
#5+8
# i am 2nd
# 12
#hello
#11

# %%
# Create four functions
# def add(a+b):
# print(a+b)
# sub
# mul
# div
# def main():
# you need to provide some print statements
# if you want enter 1 :addition operation willcome
# if you want enter 2: subtract
# if you enter 3: mul
# if you enter 4: div
# operaion=input("enter a number")
# a=eval(input())
# b=eval(inpu())
# if operation=='1':
# add(a,b)
# if operation=='2':
# sub(a,b)
# if operation=='3':
# mul(a,b)
# if operation=='4':
# div(a,b)

# %%
# defining all the function 
import time
def add(a,b):
    print("we are doing addition")
    print("the sum of {} and {} is {}".format(a,b,a+b))
def sub(a,b):
    print("we are doing substraction")
    print("the subtraction of {} and {} is {}".format(a,b,a-b))
def mul(a,b):
    print("we are doing multiplication")
    print("the multiplication of {} and {} is {}".format(a,b,a*b))

def div(a,b):
     print("we are doing division")
     print("the division of {} and {} is {}".format(a,b,a/b))

    
#defining main function to enter the operation and values
def main():
    print("Welcome")
    print("*************************************************")
    print("**** Here are options****")
    time.sleep(1)
    # printing operations
    print("For addition press + ")
    print("For multiplication press * ")
    print("For division press / ")
    print("For addition press - ")
    op=input("Please choose which operation you want to perform form above")
    time.sleep(0.3)
    # taking numbers as input from users
    time.sleep(1)
    
    # calling each function 
    if op=="+":
        # taking input if operation match this is done becuase if invalid input enter no value will ask from user
        x=eval(input("Enter first number:"))
        y=eval(input("Enter second number:"))
        add(x,y)
    elif op=="-":
        x=eval(input("Enter first number:"))
        y=eval(input("Enter second number:"))
        sub(x,y)
    elif op=="*":
        x=eval(input("Enter first number:"))
        y=eval(input("Enter second number:"))
        mul(x,y)
    elif op=="/":
        x=eval(input("Enter first number:"))
        y=eval(input("Enter second number:"))
        div(x,y)
    else:
        print("Please choose the correct option")


# calling main function and then main function will call the required operation as per the input
main()
print("Thank you !")

# %%
# using return

# %%
# defining all the function 
import time
def add(a,b):
    print("we are doing addition")
    return a+b
def sub(a,b):
    print("we are doing substraction")
    return a-b
def mul(a,b):
    print("we are doing multiplication")
    return a*b

def div(a,b):
     print("we are doing division")
     return (round(a/b,2))
    

    
#defining main function to enter the operation and values
def main():
    print("Welcome")
    print("*************************************************")
    print("**** Here are options****")
    time.sleep(1)
    # printing operations
    print("For addition press + ")
    print("For multiplication press * ")
    print("For division press / ")
    print("For addition press - ")
    op=input("Please choose which operation you want to perform form above")
    time.sleep(0.3)
    # taking numbers as input from users
    time.sleep(1)
    
    # calling each function 
    # we can recieve the return value by 2 way by directly calling through print statement
    #by using a variable store the return value then print
    if op=="+":
        # taking input if operation match this is done becuase if invalid input enter no value will ask from user
        x=eval(input("Enter first number:"))
        y=eval(input("Enter second number:"))
        print("the sum {} and {} is {} ".format(x,y,add(x,y))) # calling the function and printing in same line
        
    elif op=="-":
        x=eval(input("Enter first number:"))
        y=eval(input("Enter second number:"))
        s=sub(x,y)# storing the return value is s and then printing another way 2
        print("the subtract {} and {} is {}".format(x,y,s))
        
    elif op=="*":
        x=eval(input("Enter first number:"))
        y=eval(input("Enter second number:"))
        print("the multiplication is ",mul(x,y)) # another way 3 to call and recieve the return valuse
    elif op=="/":
        x=eval(input("Enter first number:"))
        y=eval(input("Enter second number:"))
        print("the division is ", div(x,y))
    else:
        print("Please choose the correct option")


# calling main function and then main function will call the required operation as per the input
main()
print("Thank you !")
# Out:
# Welcome
# *************************************************
# **** Here are options****
# For addition press +
# For multiplication press *
# For division press /
# For addition press -
# Please choose which operation you want to perform form above *
# Enter first number: 2
# Enter second number: 3
# we are doing multiplication
# the multiplication is  6
# Thank you !

# %% [markdown]
# ## keyword arguments ##
# - key word arguments pass duing call of function
# - you cannot write positional arguments after the keyword arguments
# - we can't provide postinaly argument after the keywoed it will give complile time error
# - if we provide postinal argument and then again provide the keyword for the same variable then it is run time error multiple
# - value for same variable
#      eg # here it will give runtime error as with positianl arg a will take 2 and with keyword arg a will take 1 so it will give
#         -run time error as muliple values
#         def fun(a,b):
#             print(f" a: {a} and b: is {b}")
#         fun(2,a=1)

# %%
# default argument always give on funciton define
def fun(a,b=10):
    print(f" a: {a} and b: is {b}")
fun(2)
# Out:
#  a: 2 and b: is 10

# %%
# keyword  argument always give on function call
# postinaly arguments
def fun(a,b):
    print(f" a: {a} and b: is {b}")
fun(1,2)
# Out:
#  a: 1 and b: is 2

# %%
# i wnat to provide b fiest and then a
# 
def fun(a,b):
    print(f" a: {a} and b: is {b}")
fun(b=1,a=2)  # keyword argument
# Out:
#  a: 2 and b: is 1

# %%
# we can't provide postinaly argument after the keywoed it will give complile time error
def fun(a,b):
    print(f" a: {a} and b: is {b}")
fun(b=1,a)
# Out:
#   Cell In[6], line 3
#     fun(b=1,a)
#              ^
# SyntaxError: positional argument follows keyword argument

# %%
# here it will give runtime error as with positianl arg a will take 2 and with keyword arg a will take 1 so it will give
# run time error as muliple values
def fun(a,b):
    print(f" a: {a} and b: is {b}")
fun(2,a=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 5
#       3 def fun(a,b):
#       4     print(f" a: {a} and b: is {b}")
# ----> 5 fun(2,a=1)
#
# TypeError: fun() got multiple values for argument 'a'

# %% [markdown]
# $ variable -length - arguments $
# - it use to pass tuple and each elemment of tuple
# - or we can say that when require to pass any number of arguement in function
# - during call arg is pass as element of tuple
# - if we want to pass a tuple then we have write *tuple name during call
# - def(*t) it always meand t is a tuple

# %%
# here are we are strickt to pass only two var to and the avg is find to only two var
def average(a,b):
    return (a+b)/2
print("avg is {}".format(average(1,2)))
# Out:
# avg is 1.5

# %%
what if i want to calcaluat 3,4 5 and more varialbe avg then every time we have to do modification in the code

# %%
# so we are usiing varialbe lenght argument in that case 
def avg(*varialbe) here once you put star the varialbe is work as tuple 

call  avg(1,2,3,4) # 1,2,3,4 will pass as element of tuple

# %%
def avg(*t):
    # as t is tuple now
    return (sum(t)/len(t))
    # sum will give teh sum of element and len t will give len of tuple
print("the average is :",round(avg(6,4,10),2))
# Out:
# the average is : 6.67

# %%
# passing tuple 
def fun(*t):
    print(t)
t1=(1,2,3,5)
fun(t1)# here t1 is pass as element of tuple
# Out:
# ((1, 2, 3, 5),)

# %%
def fun(*t):
    print(t)
t1=(1,2,3,5)
fun(*t1)# here t1 is pass as tuple by * witing before name of tuple during call
# Out:
# (1, 2, 3, 5)

# %% [markdown]
# $ variable - lenghth - keyword - arguments $
#
# - in this we use during defination of fun **variable name
#
#      - def(**d) d is a dictionary
#
# - in this we are makeing a dictionary
#
# - so during call we need to pass the key and value pair
#
# - if we want to pass entire dictionary we should write during call **dictionary anme
#
# - NOTE in this we only pass key as str we cannot pass key as other data type it must be str
#
# - during call(ritesh:23) # ritesh is str default and 23 is int if wirte like this "ritesh"=23 it will show error pass without quote as alwats
#
# - treat as str
#
# - while passing the entire dicionay also we must pass that dic in which key are str otherwaise error

# %%
# items method of dic return list  of tuple 
d1={1:"ritesh",2:"ajay"}
d1.items()
# Out:
# dict_items([(1, 'ritesh'), (2, 'ajay')])

# %%
def fun1(**d):
    for i,j in d.items() :
        print(f"{i} has age is {j}")
       # print(type(i))
       # print(type(j))
fun1(ritesh=24,ajay=25,kalu=29)    # passing keys and their values
# we can't pass key as int,  error will show 
# pass the key as str without quotes they will treat as str 
# in value or right side we can pass any this str or int 
# but in left side or key side only str will pass without quotes
# Out:
# ritesh has age is 24
# ajay has age is 25
# kalu has age is 29

# %%
# passing entire dicitonay
# we need to pass **d at time of call
# while passing the entire dicionary also we musst use the key as dicionary
def fun2(**d):
    for i,j in d.items() :
        print(f"{i} is of  {j}")
       # print(type(i))
       # print(type(j))
d1={24:"ritesh",25:"ajay"} 
d1
fun2(**d1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[64], line 11
#       9 d1={24:"ritesh",25:"ajay"}
#      10 d1
# ---> 11 fun2(**d1)
#
# TypeError: keywords must be strings

# %%
# passing entire dicitonay
# we need to pass **d at time of call
# while passing the entire dicionary also we musst use the key as dicionary
def fun2(**d):
    for i,j in d.items() :
        print(f"{i} has age  {j}")
       # print(type(i))
       # print(type(j))
d1={"ritesh":23,"ajay":90} 
d1
fun2(**d1)
# Out:
# ritesh has age  23
# ajay has age  90
